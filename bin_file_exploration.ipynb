# %%
from PIL import Image

print im.size #Get the width and hight of the image for iterating over
print pix[0,0] #Get the RGBA Value of the a pixel of an image
# pix[x,y] = value
# Out:
# (80, 60)
# (39, 39, 39)

# %%
pix[40,30]
# Out:
# (186, 31, 109)

# %%
import json
from IPython.display import Image as ipython_image
# json1_data = json.loads(json1_str)[0]

# %%
file = open('predict_thermal.txt')
for line in file:
#     print (json.loads(line))
#     filename = ''
    if "rgb" in line:
#         print line
        filename = line
    try: 
        if json.loads(line):
            line = json.loads(line)
            print filename
            im = Image.open(filename.replace("\n",'')) #Can be many different formats.
            pix = im.load()
#             print pix
#             print line['bbox']
#             detected_box = im.crop((int(line['bbox'][0]['left']), int(line['bbox'][1]['top']), int(line['bbox'][2]['right']), int(line['bbox'][3]['bottom'])))
#             ipython_image(detected_box)
            for y in range(int(line['bbox'][1]['top']), int(line['bbox'][3]['bottom'])):
                for x in range(int(line['bbox'][0]['left']), int(line['bbox'][2]['right'])):
                    print pix[x, y]
    except ValueError as e:
        continue
# Out:
# rgb1.jpg
#
# (104, 104, 104)
# (102, 102, 102)
# (94, 94, 94)
# (107, 107, 105)
# (117, 119, 118)
# (130, 131, 133)
# (120, 120, 120)
# (129, 129, 127)
# (124, 125, 120)
# (119, 123, 122)
# (120, 128, 131)
# (123, 126, 133)
# (125, 123, 126)
# (97, 93, 92)
# (89, 87, 88)
# (83, 84, 86)
# (85, 86, 88)
# (143, 143, 143)
# (137, 137, 137)
# (127, 125, 126)
# (137, 137, 139)
# (161, 161, 163)
# (177, 177, 175)
# (177, 177, 175)
# (169, 169, 171)
# (158, 153, 159)
# (152, 142, 143)
# (153, 140, 134)
# (150, 141, 132)
# (143, 144, 139)
# (99, 103, 104)
# (91, 92, 94)
# (87, 86, 84)
# (85, 83, 84)
# (110, 110, 110)
# (129, 129, 129)
# (134, 133, 129)
# (149, 148, 153)
# (179, 178, 183)
# (217, 218, 213)
# (245, 246, 240)
# (230, 227, 234)
# (205, 184, 199)
# (165, 126, 119)
# (76, 30, 0)
# (95, 66, 24)
# (148, 147, 129)
# (74, 85, 91)
# (72, 77, 83)
# (70, 65, 61)
# (71, 68, 63)
# (23, 23, 25)
# (106, 106, 108)
# (115, 117, 112)
# (138, 136, 141)
# (172, 167, 173)
# (202, 205, 198)
# ...

# %%
file = open('dataset-1/raw22.bin')
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==0:
        new_hex_list.append(hex_list[i]+hex_list[i+1])

# %%
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==0:
        new_hex_list.append(hex_list[i]+hex_list[i+1])

# %%
for i in new_hex_list:
    print i
# Out:
# 1E48
# 1F8B
# 661E
# 5F1E
# 661E
# 671E
# 691E
# 6F1E
# 6B1E
# 6D1E
# 731E
# 771E
# 721E
# 731E
# 751E
# 761E
# 761E
# 7A1E
# 7A1E
# 7C1E
 30 118 30 116 30 115 30 118 30 116 30 114 30 110 30 112 30 114 30 113 30 116 30 111 30 112 30 110 30 112 30 108 30 111 30 110 30 110 30 108 30 117 30 114 30 115 30 118 30 117 30 118 30 111 30 111 30 111 30 110 30 108 30 103 30 103 30 107 30 108 30 102 30 104 30 109 30 108 30 106 30 111 30 110 30 115 30 116 30 119 30 110 30 112 30 109 30 111 30 111 30 116 30 109 30 110 30 108 30 113 30 114 30 109 30 107 30 100 30 102 30 104 30 99 30"""
len(a.split(" "))
# Out:
# 9604

# %%
import math

# %%
pixels = []
for i in new_hex_list:
    x = int(i,16)
#     if x > 0x7FFFFFFF:
#         x -= 0x100000000
    pixels.append(int(math.floor(x/256)))

# %%
from PIL import Image
data = ""
for i in range(2,60*80+2):
    data += chr(pixels[i]) + chr(pixels[i]) + chr(pixels[i])
im = Image.frombytes("RGB", (80,60), data)
im.save("test.png", "PNG")

# %%
def interpret_bin_file(filename, target):
    file = open(filename)
    hex_list = []
    for line in file:
        hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
    new_hex_list = []
    for i, v in enumerate(hex_list):
        if i%2==0:
            new_hex_list.append(hex_list[i]+hex_list[i+1])
    pixels = []
    for i in new_hex_list:
        x = int(i,16)
        pixels.append(int(math.floor(x/256)))
    data = ""
    for i in range(2,60*80+2):
        data += chr(pixels[i]) + chr(pixels[i]) + chr(pixels[i])
    im = Image.frombytes("RGB", (80,60), data)
    im.save(target, "PNG")

# %%
file = open("dataset-1/raw31.bin")
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==0:
        new_hex_list.append(int(hex_list[i]+hex_list[i+1], 16))
txt_file = ""
for i in range(0,60):
    for j in range(0, 80):
        txt_file+=str(new_hex_list[i*j+2])+" "
    txt_file+="\n "
text_file = open("raw31.txt", "w")
text_file.write(txt_file)
text_file.close()

# %%
print txt_file
# Out:
# 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334 34334
#  34334 32286 32798 32286 34078 32542 32542 32542 33310 33566 33310 34590 33310 33566 34590 34334 34590 34590 33310 33310 33822 33054 33566 33566 32030 32542 33822 31774 32798 32542 32798 31774 32798 31774 32542 31518 32286 31774 31774 31262 32286 31774 32286 30494 30750 30494 30494 30750 29982 30494 28958 30238 28702 28446 28702 28702 27934 30238 28958 28190 26654 24862 26910 26910 27934 28190 27166 27166 26654 27166 27422 26398 25630 25630 24862 23838 24350 25374 23326 21790
# ...

# %%
def interpret_bin_file_as_img(filename, target):
    file = open(filename)
    hex_list = []
    for line in file:
        hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
    new_hex_list = []
    for i, v in enumerate(hex_list):
        if i%2==0:
            new_hex_list.append(hex_list[i]+hex_list[i+1])
    pixels = []
    for i in new_hex_list:
        x = int(i,16)
        pixels.append(int(math.floor(x/256)))
    data = ""
    for i in range(2,60*80+2):
        data += chr(pixels[i]) + chr(pixels[i]) + chr(pixels[i])
    im = Image.frombytes("RGB", (80,60), data)
    im.save(target, "PNG")
def interpret_bin_file_as_txt_file(filename, target):
    file = open(filename)
    hex_list = []
    for line in file:
        hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
    new_hex_list = []
    for i, v in enumerate(hex_list):
        if i%2==0:
            new_hex_list.append(int(hex_list[i]+hex_list[i+1], 16))
    txt_file = ""
    for i in range(0,60):
        for j in range(0, 80):
            txt_file+=str(new_hex_list[i*j+2])+" "
        txt_file+="\n "
    text_file = open(target, "w")
    text_file.write(txt_file)
    text_file.close()

# %%
import math
from PIL import Image

# %%
interpret_bin_file_as_txt_file('dataset-6/raw105.bin','raw105.txt')
interpret_bin_file_as_img('dataset-6/raw105.bin','raw105.png')

# %%
file = open('dataset-1/raw38.bin')
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==0:
        new_hex_list.append((hex_list[i]+hex_list[i+1]))
pixels = []
for i, v in enumerate(new_hex_list):
    if i ==0 or i == 1:
        continue
    else:
#         print (list("{0:b}".format(int(v, 16))))
        final = []
        for i, v in enumerate(list("{0:b}".format(int(v, 16)))):
#             print i, v
            if i == 0 or i == 1:
                final.append('0')
            else:
                final.append(v)
        pixels.append(int(''.join(final),2)/64)
data = ""
for i in range(0,60*80):
    data += chr(pixels[i]) + chr(pixels[i]) + chr(pixels[i])
im = Image.frombytes("RGB", (80,60), data)
im.save('raw38.png', "PNG")
#         ''.join[v if i != 0 or i != 1 else 0 for i, v in enumerate(list("{0:b}".format(int(v, 16))))]

# %%
file = open('dataset-6/raw109.bin')
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==1 and i != 0 and i!=1 and i != (len(hex_list)-1):
        new_hex_list.append((hex_list[i],hex_list[i+1]))
#         new_hex_list.append(int(hex_list[i]+hex_list[i+1], 16))
# txt_file = ""
# for i in range(0,60):
#     for j in range(0, 80):
#         txt_file+=str(new_hex_list[i*j])+" "
#     txt_file+="\n "
# print txt_file
# print (hex_list)
# print new_hex_list
# print new_hex_list
vals = [(int(r[0],16),int(r[1],16)) for r in new_hex_list]
print len(vals)
data = ""
for i in range(0,60*80):
    data += chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16))
im = Image.frombytes("RGB", (80,60), data)
im.save('raw109-3.png', "PNG")
data = ""
for i in range(0,60*80):
    data += chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16))
im = Image.frombytes("RGB", (80,60), data)
im.save('raw109-4.png', "PNG")
# Out:
# 4800

# %%
file = open('dataset-6/raw109.bin')
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i in range(len(hex_list)/2):
#     print i, v
    new_hex_list.append(list(str(hex_list[2*i]))[1]+list(str(hex_list[2*i+1]))[0])

# for i, v in enumerate(hex_list):
#     if i%2==1 and i != 0 and i!=1 and i != (len(hex_list)-1):
#         new_hex_list.append((hex_list[i],hex_list[i+1]))
# #         new_hex_list.append(int(hex_list[i]+hex_list[i+1], 16))
# # txt_file = ""
# # for i in range(0,60):
# #     for j in range(0, 80):
# #         txt_file+=str(new_hex_list[i*j])+" "
# #     txt_file+="\n "
# # print txt_file
# # print (hex_list)
# # print new_hex_list
# # print new_hex_list
# vals = [(int(r[0],16),int(r[1],16)) for r in new_hex_list]
# print len(vals)
# data = ""
# for i in range(0,60*80):
#     data += chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16))
# im = Image.frombytes("RGB", (80,60), data)
# im.save('raw109-3.png', "PNG")
# data = ""
# for i in range(0,60*80):
#     data += chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16))
# im = Image.frombytes("RGB", (80,60), data)
# im.save('raw109-4.png', "PNG")
pixels=[]
for i in new_hex_list:
    x = int(i,16)
    pixels.append(x)
data = ""
for i in range(2,60*80+2):
    data += chr(pixels[i]) + chr(pixels[i]) + chr(pixels[i])
im = Image.frombytes("RGB", (80,60), data)
im.save('raw109-6.png', "PNG")

# %%
new_hex_list
# Out:
# ['92',
#  '08',
#  '4F',
#  '01',
#  'EF',
#  '51',
#  'EF',
#  '21',
#  'EF',
#  '31',
#  'EE',
#  'E1',
#  'EF',
#  '01',
#  'EE',
#  'F1',
#  'EE',
#  '91',
#  'EE',
#  'B1',
#  'EE',
#  'B1',
#  'EE',
#  '51',
#  'EE',
#  '81',
#  'EE',
#  '71',
#  'EE',
#  '51',
#  'EE',
#  '21',
#  'EE',
#  '11',
#  'ED',
#  'E1',
#  'ED',
#  'A1',
#  'ED',
#  'D1',
#  'ED',
#  'C1',
#  'ED',
#  'A1',
#  'ED',
#  'B1',
#  'ED',
#  '61',
#  'ED',
#  'B1',
#  'ED',
#  '71',
#  'ED',
#  '11',
#  'ED',
#  '31',
#  'ED',
#  '41',
#  'EC',
#  'F1',
#  'ED',
#  '11',
#  'EC',
#  'F1',
#  'EC',
#  'C1',
#  'EC',
#  'D1',
#  'EC',
#  'D1',
#  'EC',
#  'B1',
#  'EC',
#  'C1',
#  'EC',
#  'D1',
#  'EC',
#  'F1',
#  'ED',
#  '21',
#  'EC',
#  'F1',
#  'ED',
#  '01',
#  'ED',
#  '21',
#  'ED',
#  '21',
#  'ED',
#  '31',
#  'EC',
#  'E1',
#  'ED',
#  '21',
#  'EC',
#  'F1',
#  'ED',
#  '11',
#  'ED',
#  '21',
#  'EC',
#  'C1',
#  'ED',
#  '21',
#  'EC',
#  'D1',
#  'ED',
#  '41',
#  'EC',
#  'D1',
#  'ED',
# ...

# %%
interpret_bin_file_as_img('dataset-6/raw109.bin','raw109-5.png')

# %%
file = open('dataset-6/raw112.bin')
hex_list = []
for line in file:
    hex_list.extend((''.join( [ "%02X " % ord( x ) for x in line ] ).strip()).split(" "))
new_hex_list = []
for i, v in enumerate(hex_list):
    if i%2==0:
        new_hex_list.append((hex_list[i],hex_list[i+1]))
pixels = []
# for i in new_hex_list:
# #     x = int(i[0],16)
#     pixels.append(int(math.floor(x/256)))
data = ""
for i in range(2,60*80+2):
    data += chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16)) + chr(int(new_hex_list[i][0], 16))
im = Image.frombytes("RGB", (80,60), data)
im.save('raw112.png', "PNG")
data = ""
for i in range(2,60*80+2):
    data += chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16)) + chr(int(new_hex_list[i][1], 16))
im = Image.frombytes("RGB", (80,60), data)
im.save('raw112-2.png', "PNG")

# %%
from interpret_bin_file import interpret_bin_file_as_txt_file, interpret_bin_file_as_img

# %%
interpret_bin_file_as_img('dataset-1/raw38.bin','raw38-2.png')

# %%
from skimage import measure
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %matplotlib inline

# %%
img = cv2.imread('dataset-5/rgb79.jpg',0)
h,w = img.shape[:2]

# plt.show()
fig,ax = plt.subplots(1)
# ax.imshow(img,cmap='gray')

L = measure.label(img)
# print "Number of components:", np.max(L)
# print L

ret, thresh = cv2.threshold(img,115,255,cv2.THRESH_BINARY)
ax.imshow(thresh, cmap='gray')
output = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)

# Get the results
# The first cell is the number of labels
num_labels = output[0]
# The second cell is the label matrix
labels = output[1]
# The third cell is the stat matrix
stats = output[2]
# The fourth cell is the centroid matrix
centroids = output[3]

print num_labels
print labels, len(labels)
print stats
print centroids

# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# put a red dot, size 40, at 2 locations:
# plt.scatter(x=[centroids[0][0], centroids[1][0]], y=[centroids[0][1], centroids[1][1]], c='r', s=40)
# ax2 = plt.add_subplot(111, aspect='equal')
for i in range(len(stats)):
    if stats[i][0]==0 and stats[i][1]==0:
        continue
    ax.add_patch(
        patches.Rectangle(
            (stats[i][0], stats[i][1]),
            stats[i][2],
            stats[i][3],
            fill=False,      # remove background
            color='red'
        )
    )
# fig2.savefig('rect2.png', dpi=90, bbox_inches='tight')
plt.show()
# Out:
# 5
# [[0 0 1 ..., 2 2 2]
#  [1 1 1 ..., 2 2 2]
#  [1 1 1 ..., 2 2 2]
#  ...,
#  [2 2 2 ..., 2 2 2]
#  [2 2 2 ..., 2 2 2]
#  [2 2 2 ..., 2 2 2]] 60
# [[   0    0   33   43  677]
#  [   0    0   16   19  175]
#  [   0    0   80   60 3930]
#  [  17    9    1    1    1]
#  [  12   14    5    7   17]]
# [[ 16.70901034  23.41211226]
#  [  5.87428571   8.45142857]
#  [ 45.0394402   31.54503817]
#  [ 17.           9.        ]
#  [ 14.          17.05882353]]
